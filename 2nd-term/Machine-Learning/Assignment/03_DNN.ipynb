# %% [markdown]
# # 3. Deep NN

# %%
import tensorflow as tf
import numpy as np

from reader import Reader

def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %% [markdown]
# ## 3.1 Data
#
# 5 fold cross validation 사용

# %%
my_reader = Reader()
X_data, y_data, id_data = my_reader.get_entire_data()

# %%
# 5 fold
X_splited = np.array_split(X_data, 5)
y_splited = np.array_split(y_data, 5)
folds_X = []
folds_y = []
for idx in range(5):
    tmp_train_X = np.concatenate(np.delete(X_splited, idx, axis=0))
    tmp_val_X = X_splited[idx]
    folds_X.append((tmp_train_X, tmp_val_X))
    
    tmp_train_y = np.concatenate(np.delete(y_splited, idx, axis=0))
    tmp_val_y = y_splited[idx]
    folds_y.append((tmp_train_y, tmp_val_y))

# %% [markdown]
# ## 3.2 Model
#
# - he initializer 사용
# - ReLU 사용
# - 구성: 30 neurons, 3 layers

# %%
he_init = tf.contrib.layers.variance_scaling_initializer() # he initializer

# dnn model: 100 neurons for each 5 hidden layers
def dnn(inputs, n_hidden_layers=3, n_neurons=50, name=None,
        activation=tf.nn.relu, initializer=he_init):
    with tf.variable_scope(name, "dnn"):
        for layer in range(n_hidden_layers):
            inputs = tf.layers.dense(inputs, n_neurons, activation=activation,
                                     kernel_initializer=initializer,
                                     name="hidden%d" % (layer + 1))
        return inputs

# %%
n_inputs = 30 # 30 features
n_outputs = 2 # M, B

reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

dnn_outputs = dnn(X)

logits = tf.layers.dense(dnn_outputs, n_outputs, kernel_initializer=he_init, name="logits")
Y_proba = tf.nn.softmax(logits, name="Y_proba")

# %% [markdown]
# - learning rate : 0.01
# - loss : cross entropy 사용
# - optimizer : Adam
# - top 1 rate 사용

# %%
learning_rate = 0.01

# entropy as loss
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
loss = tf.reduce_mean(xentropy, name="loss")

# Adam optimizer minimizes loss
optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss, name="training_op")

# top 1 rate
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")

init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# ## 3.3 Training
#
# - Early stopping : loss를 더 줄이지 못한채 학습하는 epoch이 내가 설정한 횟수(20) 이상이 되면 멈춘다.
# - 최고 accuracy가 나왔을 때 Saver를 활용해서 그 때의 weight 값을 저장해둔다. epoch이 끝났을 때 최고 weight를 불러와서 전체 training data에 적용해서 accuracy 측정
# - 5 fold로 아래 코드의 data_idx를 0에서 4까지 바꿔가며 학습해보았다.
#     + 0: 90.16%
#     + 1: 95.08%
#     + 2: 93.85%
#     + 3: 93.50%
#     + 4: 93.02%
# - 평균 accuracy : 93.18%

# %%
data_idx = 4 # Check 0 to 4
kfold_data_X = folds_X[data_idx]
kfold_data_y = folds_y[data_idx]
n_epochs = 1000
batch_size = 20 # mini batch size

max_checks_without_progress = 20
checks_without_progress = 0
best_loss = np.infty

with tf.Session() as sess:
    init.run()

    for epoch in range(n_epochs):
        rnd_idx = np.random.permutation(len(kfold_data_X[0])) # 숫자만큼 인덱스 랜덤 정렬
        for rnd_indices in np.array_split(rnd_idx, len(kfold_data_X[0]) // batch_size): # rnd_idx 리스트를 둘째 매개변수 개수만큼으로 쪼갬
            X_batch, y_batch = kfold_data_X[0][rnd_indices], kfold_data_y[0][rnd_indices] # 쪼갠걸로 그 때 그 때 배치 만들고 학습
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        loss_val, acc_val = sess.run([loss, accuracy], feed_dict={X: kfold_data_X[1], y: kfold_data_y[1]})
        
        # 가장 작은 loss 값을 갱신해감. 갱신하면 checks를 0으로
        if loss_val < best_loss:
            save_path = saver.save(sess, "./dnn_checkpoints/wdbc.ckpt")
            best_loss = loss_val
            checks_without_progress = 0
        # loss 값을 더 줄이지 못한채 max 이상 epoch를 돌면 early stopping
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print("Early stopping!")
                break
        print("{}\tValidation loss: {:.6f}\tBest loss: {:.6f}\tAccuracy: {:.2f}%".format(
            epoch, loss_val, best_loss, acc_val * 100))

with tf.Session() as sess:
    saver.restore(sess, "./dnn_checkpoints/wdbc.ckpt")
    acc_test = accuracy.eval(feed_dict={X: X_data, y: y_data})
    print("Final test accuracy: {:.2f}%".format(acc_test * 100))
# Out:
# 0	Validation loss: 4.281433	Best loss: 4.281433	Accuracy: 75.22%
# 1	Validation loss: 1.074118	Best loss: 1.074118	Accuracy: 92.04%
# 2	Validation loss: 0.966664	Best loss: 0.966664	Accuracy: 91.15%
# 3	Validation loss: 2.910038	Best loss: 0.966664	Accuracy: 68.14%
# 4	Validation loss: 1.482485	Best loss: 0.966664	Accuracy: 92.04%
# 5	Validation loss: 2.366786	Best loss: 0.966664	Accuracy: 92.04%
# 6	Validation loss: 1.266086	Best loss: 0.966664	Accuracy: 94.69%
# 7	Validation loss: 0.729205	Best loss: 0.729205	Accuracy: 92.04%
# 8	Validation loss: 1.166198	Best loss: 0.729205	Accuracy: 92.04%
# 9	Validation loss: 1.186710	Best loss: 0.729205	Accuracy: 74.34%
# 10	Validation loss: 0.424935	Best loss: 0.424935	Accuracy: 90.27%
# 11	Validation loss: 0.222514	Best loss: 0.222514	Accuracy: 92.04%
# 12	Validation loss: 0.194688	Best loss: 0.194688	Accuracy: 92.04%
# 13	Validation loss: 0.215423	Best loss: 0.194688	Accuracy: 92.92%
# 14	Validation loss: 0.343392	Best loss: 0.194688	Accuracy: 88.50%
# 15	Validation loss: 0.195561	Best loss: 0.194688	Accuracy: 92.04%
# 16	Validation loss: 0.316602	Best loss: 0.194688	Accuracy: 89.38%
# 17	Validation loss: 0.244183	Best loss: 0.194688	Accuracy: 91.15%
# 18	Validation loss: 0.198677	Best loss: 0.194688	Accuracy: 94.69%
# 19	Validation loss: 0.301536	Best loss: 0.194688	Accuracy: 88.50%
# 20	Validation loss: 0.199780	Best loss: 0.194688	Accuracy: 92.04%
# 21	Validation loss: 0.213851	Best loss: 0.194688	Accuracy: 92.04%
# 22	Validation loss: 0.204718	Best loss: 0.194688	Accuracy: 92.04%
# 23	Validation loss: 0.309158	Best loss: 0.194688	Accuracy: 90.27%
# 24	Validation loss: 0.218946	Best loss: 0.194688	Accuracy: 92.04%
# 25	Validation loss: 0.195420	Best loss: 0.194688	Accuracy: 93.81%
# 26	Validation loss: 0.199841	Best loss: 0.194688	Accuracy: 92.92%
# 27	Validation loss: 0.219272	Best loss: 0.194688	Accuracy: 91.15%
# 28	Validation loss: 0.200499	Best loss: 0.194688	Accuracy: 94.69%
# 29	Validation loss: 0.247025	Best loss: 0.194688	Accuracy: 91.15%
# 30	Validation loss: 0.189553	Best loss: 0.189553	Accuracy: 92.04%
# 31	Validation loss: 0.200539	Best loss: 0.189553	Accuracy: 92.04%
# 32	Validation loss: 0.279728	Best loss: 0.189553	Accuracy: 90.27%
# 33	Validation loss: 0.316157	Best loss: 0.189553	Accuracy: 87.61%
# 34	Validation loss: 0.185374	Best loss: 0.185374	Accuracy: 92.92%
# 35	Validation loss: 0.220595	Best loss: 0.185374	Accuracy: 92.92%
# 36	Validation loss: 0.211706	Best loss: 0.185374	Accuracy: 93.81%
# 37	Validation loss: 0.465877	Best loss: 0.185374	Accuracy: 82.30%
# 38	Validation loss: 0.181557	Best loss: 0.181557	Accuracy: 94.69%
# 39	Validation loss: 0.234827	Best loss: 0.181557	Accuracy: 90.27%
# 40	Validation loss: 0.256764	Best loss: 0.181557	Accuracy: 92.04%
# 41	Validation loss: 0.171366	Best loss: 0.171366	Accuracy: 93.81%
# 42	Validation loss: 0.270527	Best loss: 0.171366	Accuracy: 89.38%
# 43	Validation loss: 0.197935	Best loss: 0.171366	Accuracy: 92.92%
# 44	Validation loss: 0.184800	Best loss: 0.171366	Accuracy: 93.81%
# 45	Validation loss: 0.233867	Best loss: 0.171366	Accuracy: 92.04%
# 46	Validation loss: 0.162591	Best loss: 0.162591	Accuracy: 92.92%
# 47	Validation loss: 0.191154	Best loss: 0.162591	Accuracy: 92.04%
# 48	Validation loss: 0.189199	Best loss: 0.162591	Accuracy: 92.04%
# 49	Validation loss: 0.196760	Best loss: 0.162591	Accuracy: 93.81%
# 50	Validation loss: 0.196837	Best loss: 0.162591	Accuracy: 92.04%
# 51	Validation loss: 0.219209	Best loss: 0.162591	Accuracy: 93.81%
# 52	Validation loss: 0.302968	Best loss: 0.162591	Accuracy: 87.61%
# 53	Validation loss: 0.298098	Best loss: 0.162591	Accuracy: 87.61%
# 54	Validation loss: 0.222580	Best loss: 0.162591	Accuracy: 92.92%
# 55	Validation loss: 0.161537	Best loss: 0.161537	Accuracy: 93.81%
# 56	Validation loss: 0.165052	Best loss: 0.161537	Accuracy: 94.69%
# 57	Validation loss: 0.180746	Best loss: 0.161537	Accuracy: 92.92%
# 58	Validation loss: 0.190892	Best loss: 0.161537	Accuracy: 92.92%
# 59	Validation loss: 0.202226	Best loss: 0.161537	Accuracy: 92.04%
# 60	Validation loss: 0.165822	Best loss: 0.161537	Accuracy: 93.81%
# 61	Validation loss: 0.185968	Best loss: 0.161537	Accuracy: 92.92%
# 62	Validation loss: 0.166116	Best loss: 0.161537	Accuracy: 92.92%
# 63	Validation loss: 0.162126	Best loss: 0.161537	Accuracy: 94.69%
# 64	Validation loss: 0.167211	Best loss: 0.161537	Accuracy: 92.92%
# 65	Validation loss: 0.213668	Best loss: 0.161537	Accuracy: 92.92%
# 66	Validation loss: 0.206124	Best loss: 0.161537	Accuracy: 93.81%
# 67	Validation loss: 0.163349	Best loss: 0.161537	Accuracy: 94.69%
# 68	Validation loss: 0.320716	Best loss: 0.161537	Accuracy: 87.61%
# 69	Validation loss: 0.177887	Best loss: 0.161537	Accuracy: 93.81%
# 70	Validation loss: 0.156959	Best loss: 0.156959	Accuracy: 93.81%
# 71	Validation loss: 0.185815	Best loss: 0.156959	Accuracy: 93.81%
# 72	Validation loss: 0.173941	Best loss: 0.156959	Accuracy: 93.81%
# 73	Validation loss: 0.158315	Best loss: 0.156959	Accuracy: 92.92%
# 74	Validation loss: 0.182789	Best loss: 0.156959	Accuracy: 93.81%
# 75	Validation loss: 0.156185	Best loss: 0.156185	Accuracy: 93.81%
# 76	Validation loss: 0.183989	Best loss: 0.156185	Accuracy: 93.81%
# 77	Validation loss: 0.161939	Best loss: 0.156185	Accuracy: 93.81%
# 78	Validation loss: 0.185356	Best loss: 0.156185	Accuracy: 93.81%
# 79	Validation loss: 0.206085	Best loss: 0.156185	Accuracy: 93.81%
# 80	Validation loss: 0.182793	Best loss: 0.156185	Accuracy: 93.81%
# 81	Validation loss: 0.204542	Best loss: 0.156185	Accuracy: 93.81%
# 82	Validation loss: 0.255535	Best loss: 0.156185	Accuracy: 89.38%
# 83	Validation loss: 0.268124	Best loss: 0.156185	Accuracy: 87.61%
# 84	Validation loss: 0.151257	Best loss: 0.151257	Accuracy: 95.58%
# 85	Validation loss: 0.156445	Best loss: 0.151257	Accuracy: 93.81%
# 86	Validation loss: 0.194506	Best loss: 0.151257	Accuracy: 92.92%
# 87	Validation loss: 0.154896	Best loss: 0.151257	Accuracy: 95.58%
# 88	Validation loss: 0.235327	Best loss: 0.151257	Accuracy: 92.04%
# 89	Validation loss: 0.179748	Best loss: 0.151257	Accuracy: 92.04%
# 90	Validation loss: 0.259152	Best loss: 0.151257	Accuracy: 90.27%
# 91	Validation loss: 0.153739	Best loss: 0.151257	Accuracy: 95.58%
# 92	Validation loss: 0.158871	Best loss: 0.151257	Accuracy: 95.58%
# 93	Validation loss: 0.195125	Best loss: 0.151257	Accuracy: 93.81%
# 94	Validation loss: 0.222134	Best loss: 0.151257	Accuracy: 92.92%
# 95	Validation loss: 0.143487	Best loss: 0.143487	Accuracy: 93.81%
# 96	Validation loss: 0.143562	Best loss: 0.143487	Accuracy: 93.81%
# 97	Validation loss: 0.232405	Best loss: 0.143487	Accuracy: 92.04%
# 98	Validation loss: 0.152345	Best loss: 0.143487	Accuracy: 96.46%
# 99	Validation loss: 0.195257	Best loss: 0.143487	Accuracy: 93.81%
# 100	Validation loss: 0.221132	Best loss: 0.143487	Accuracy: 92.04%
# 101	Validation loss: 0.184715	Best loss: 0.143487	Accuracy: 93.81%
# 102	Validation loss: 0.196186	Best loss: 0.143487	Accuracy: 93.81%
# 103	Validation loss: 0.142208	Best loss: 0.142208	Accuracy: 93.81%
# 104	Validation loss: 0.161108	Best loss: 0.142208	Accuracy: 94.69%
# 105	Validation loss: 0.284577	Best loss: 0.142208	Accuracy: 86.73%
# 106	Validation loss: 0.143927	Best loss: 0.142208	Accuracy: 93.81%
# 107	Validation loss: 0.299449	Best loss: 0.142208	Accuracy: 87.61%
# 108	Validation loss: 0.141730	Best loss: 0.141730	Accuracy: 94.69%
# 109	Validation loss: 0.321209	Best loss: 0.141730	Accuracy: 84.96%
# 110	Validation loss: 0.162994	Best loss: 0.141730	Accuracy: 95.58%
# 111	Validation loss: 0.184964	Best loss: 0.141730	Accuracy: 94.69%
# 112	Validation loss: 0.205679	Best loss: 0.141730	Accuracy: 93.81%
# 113	Validation loss: 0.228876	Best loss: 0.141730	Accuracy: 92.92%
# 114	Validation loss: 0.338143	Best loss: 0.141730	Accuracy: 82.30%
# 115	Validation loss: 0.144120	Best loss: 0.141730	Accuracy: 96.46%
# 116	Validation loss: 0.567983	Best loss: 0.141730	Accuracy: 77.88%
# 117	Validation loss: 0.145846	Best loss: 0.141730	Accuracy: 96.46%
# 118	Validation loss: 0.165097	Best loss: 0.141730	Accuracy: 94.69%
# 119	Validation loss: 0.145540	Best loss: 0.141730	Accuracy: 93.81%
# 120	Validation loss: 0.171774	Best loss: 0.141730	Accuracy: 94.69%
# 121	Validation loss: 0.377928	Best loss: 0.141730	Accuracy: 92.04%
# 122	Validation loss: 0.246061	Best loss: 0.141730	Accuracy: 92.04%
# 123	Validation loss: 0.405292	Best loss: 0.141730	Accuracy: 86.73%
# 124	Validation loss: 0.197852	Best loss: 0.141730	Accuracy: 93.81%
# 125	Validation loss: 0.185419	Best loss: 0.141730	Accuracy: 93.81%
# 126	Validation loss: 0.208271	Best loss: 0.141730	Accuracy: 92.92%
# 127	Validation loss: 0.143881	Best loss: 0.141730	Accuracy: 96.46%
# 128	Validation loss: 0.190151	Best loss: 0.141730	Accuracy: 93.81%
# Early stopping!
# INFO:tensorflow:Restoring parameters from ./dnn_checkpoints/wdbc.ckpt
# Final test accuracy: 93.32%
